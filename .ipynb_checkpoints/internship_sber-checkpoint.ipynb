# %%
import pandas as pd
import numpy as np

import datetime
from datetime import datetime, date

from statsmodels.tsa.arima.model import ARIMA

import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# считываем данные из файла
data = pd.read_csv('./data.csv', sep = ';')

# %%
data.head()
# Out:
#    REPORTDATE       VALUE
# 0  30.12.2013  3457625638
# 1  31.12.2013  3417092149
# 2  01.01.2014  3417092149
# 3  02.01.2014  3417092149
# 4  03.01.2014  3417092149

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   REPORTDATE  2111 non-null   object
#  1   VALUE       2111 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 33.1+ KB

# %%
type(data.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# ### __Приведение типов__

# %% [markdown]
# Так как я работаю с временным рядом, то необходимо сначала преобразовать дату из типф object в тип DateTime? а после назначить столбец с датами индексом

# %%
data['REPORTDATE'] = pd.to_datetime(data['REPORTDATE'], format='%d.%m.%Y')
data.set_index('REPORTDATE', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2111 entries, 2013-12-30 to 2019-10-10
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VALUE   2111 non-null   int64
# dtypes: int64(1)
# memory usage: 33.0 KB

# %%
type(data.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
data.tail()
# Out:
#                   VALUE
# REPORTDATE
# 2019-10-06  64630140507
# 2019-10-07  66115288637
# 2019-10-08  68424049766
# 2019-10-09  72492897583
# 2019-10-10  72307860851

# %% [markdown]
# ## __ИЗУЧЕНИЕ ВРЕМЕННОГО РЯДА__

# %% [markdown]
# __Визуализация__
#
# построим графики для всего периода и для каждого года. Выборочно построим графики квартальные и месячные

# %%
# визуальный анализ временного ряда за весь предоставленный период
plt.figure(figsize=(12, 4))
plt.plot(data)
plt.title('Временной ряд')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %% [markdown]
# Отчетливо видны аномалии в виде роста (увеличения вкладов) и пробития (резкого вывода денежных средств) в рамках событий 2014 года

# %%
# построим график временного ряда за 2014 год
plt.figure(figsize=(12, 2))
plt.plot(data['2013-12-30':'2014-12-31'])
plt.title('Временной ряд 2014 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за 2015 год
plt.figure(figsize=(12, 2))
plt.plot(data['2014-12-31':'2015-12-31'])
plt.title('Временной ряд 2015 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за 2016 год
plt.figure(figsize=(12, 2))
plt.plot(data['2015-12-31':'2016-12-31'])
plt.title('Временной ряд 2016 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за 2017 год
plt.figure(figsize=(12, 2))
plt.plot(data['2016-12-31':'2017-12-31'])
plt.title('Временной ряд 2017 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за 2018 год
plt.figure(figsize=(12, 2))
plt.plot(data['2017-12-31':'2018-12-31'])
plt.title('Временной ряд 2018 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за 2019 год
plt.figure(figsize=(12, 2))
plt.plot(data['2018-12-31':'2019-10-10'])
plt.title('Временной ряд 2019 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %% [markdown]
# Отчетливо наблюдаем закономерность роста и падения в течении месяца при сохранении годового тренда

# %%
# построим график временного ряда за 2 квартал 2015 года
plt.figure(figsize=(12, 2))
plt.plot(data['2015-04-01':'2015-06-30'])
plt.title('Временной ряд 2-й квартал 2015 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за 3 квартал 2017 года
plt.figure(figsize=(12, 2))
plt.plot(data['2017-07-01':'2017-09-30'])
plt.title('Временной ряд 3-й квартал 2017 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за 1 квартал 2019 года
plt.figure(figsize=(12, 2))
plt.plot(data['2019-01-01':'2019-03-31'])
plt.title('Временной ряд 1-й квартал 2019 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за июнь 2017 года
plt.figure(figsize=(12, 2))
plt.plot(data['2017-07-01':'2017-07-30'])
plt.title('Временной ряд июнь 2017 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за февраль 2018 года
plt.figure(figsize=(12, 2))
plt.plot(data['2018-02-01':'2018-02-28'])
plt.title('Временной ряд февраль 2018 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %%
# построим график временного ряда за сентябрь 2015 года
plt.figure(figsize=(12, 2))
plt.plot(data['2015-09-01':'2015-09-30'])
plt.title('Временной ряд сентябрь 2015 год')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.show()

# %% [markdown]
# На данных графиках отчетливо прослеживается следующая зависимость: макисмально накопление денежных средств происходит в середине месяца, далее идет снижение количество денежных средств и достигает минимума к концу месяца. Далее начинается рост накопления

# %%
# убрать выбросы 2014 года

# %% [markdown]
# # __Подбор модели обучения__

# %% [markdown]
# ### __ARIMA (Autoregressive Integrated Moving Average)__
